# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import KFold

# %%
print("Lung cancer prediction")

# %%
print("The project is done by a group of two people. And these are Aheebwomugisha Sasha Ana and Namuli Sylvia.")

# %%
data = pd.read_csv("cancer.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_28/1391167686.py in <module>
# ----> 1 data = pd.read_csv("cancer.csv")
#       2 data
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data.columns

# %%
data=data[['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
       'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
       'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
       'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28/3367884153.py in <module>
# ----> 1 data=data[['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#       2        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#       3        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#       4        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER']]
#
# NameError: name 'data' is not defined

# %%
data

# %%
data.isnull()

# %%
data.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28/3175101911.py in <module>
# ----> 1 data.describe()
#
# NameError: name 'data' is not defined

# %%
data.info()

# %%
correlation = data.corr()
correlation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28/3106392754.py in <module>
# ----> 1 correlation = data.corr()
#       2 correlation
#
# NameError: name 'data' is not defined

# %%
sns.heatmap(correlation,cmap="BuPu",annot=True)
plt.show()

# %%
data.plot(kind="box",figsize=(30,25))

# %%
#outliers

# %%
print(np.where(data["AGE"]>10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28/1606054950.py in <module>
# ----> 1 print(np.where(data["AGE"]>10))
#
# NameError: name 'data' is not defined

# %%
#FEATURE INDEPENDENCE PLOTS

# %%
data.hist(bins=50,figsize=(30,20))

# %%
#TRENDS IN TIME AND SPACE

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(12,10))

# %%
plt.xlabel("LUNG_CANCER")
plt.ylabel("VALUES")
plt.title("SAMPLE GRAPH")
plt.plot(data["SMOKING"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28/2855183968.py in <module>
#       2 plt.ylabel("VALUES")
#       3 plt.title("SAMPLE GRAPH")
# ----> 4 plt.plot(data["SMOKING"])
#
# NameError: name 'data' is not defined

# %%
data

# %%
len(data)

# %%
#Import models from scikit learn module:
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold 
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

# %%
x = data[['SMOKING','YELLOW_FINGERS','CHRONIC DISEASE','ALCOHOL CONSUMING','SWALLOWING DIFFICULTY','SHORTNESS OF BREATH']]
y = data['LUNG_CANCER']
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28/2904551218.py in <module>
# ----> 1 x = data[['SMOKING','YELLOW_FINGERS','CHRONIC DISEASE','ALCOHOL CONSUMING','SWALLOWING DIFFICULTY','SHORTNESS OF BREATH']]
#       2 y = data['LUNG_CANCER']
#       3 x
#
# NameError: name 'data' is not defined

# %%
x_train, x_rem, y_train, y_rem = train_test_split(x,y ,train_size=0.8)

test_size = 0.5
x_valid, x_test, y_valid, y_test = train_test_split(x_rem, y_rem, test_size = 0.5)

print(x_train.shape),print(y_train.shape)
print(x_valid.shape), print(y_valid.shape)
print(x_test.shape), print(y_test.shape)

# %%
#Generic function for making a classification odel and accessing the performance.
from sklearn.metrics import classification_report, confusion_matrix
def classification_model(model):
    #fit the model:
    model.fit(x_train, y_train)
    
    
    predictions = model.predict(x_test)
    
    accuracy = metrics.accuracy_score(y_test, predictions)
    print("Accuray: %s" % "{0:.3%}".format(accuracy))
    
    train_predictors = (x_valid)
    train_target = y_valid
    model.fit(train_predictors,train_target)
    
    model.fit(x_valid, y_valid)
    
    print(classification_report(y_test,predictions))

# %%
model = LogisticRegression()
classification_model(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28/926677097.py in <module>
# ----> 1 model = LogisticRegression()
#       2 classification_model(model)
#
# NameError: name 'LogisticRegression' is not defined

# %%
model = LogisticRegression()
classification_model(model)

# %%
model = LogisticRegression()
classification_model(model)

# %%
model = LogisticRegression()
classification_model(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28/926677097.py in <module>
# ----> 1 model = LogisticRegression()
#       2 classification_model(model)
#
# NameError: name 'LogisticRegression' is not defined
